# %% [markdown]
# # 제 8강. 벡터공간의 차원과 4가지 부벡터공간
#
# If, given linearly vectors -> linear combination => unique ( 조합은 딱 1가지이다 )
#
# basis is a maximal independent set / minimal spanning set
#
#
# ## 4 Fundamental subspaces in A
#
# How to find an explicit basis -> a systematic procedure
#
# (1) Column space
#
# $\mathbb{C}(A)$ -> linear combination of column vectors $\subset \mathbb{R}^m$
#
# (2) Null space : $N(A)$,  {$x|Ax=0$} $\subset \mathbb{R}^n$
#
# (3) Row space : $\mathbb{C}(A^T)$  => linear combination of row vectors $\subset \mathbb{R}^n$
#
# (4) Left Null space : $N(A^T)$ => {$y|A^Ty=0$}  $\subset \mathbb{R}^m$
#
#
# * $N(A)$ and $\mathbb{C}(A^T)$   are subspaces of $\subset \mathbb{R}^n$
#
# * $N(A^T)$ and $\mathbb{C}(A)$ are subspaces of  $\subset \mathbb{R}^m$
#
#
#
# ex)
# \begin{equation*}
# \mathbf{A=U=R}=\begin{bmatrix}
# 1 & 0 & 0  \\\
# 0 & 0 & 0
# \end{bmatrix}
# \end{equation*}
#
#
# \begin{equation*}
# \mathbb{C}(A)=\begin{bmatrix}
# 1   \\\
# 0
# \end{bmatrix} \subset \mathbb{R}^2
# \end{equation*}
#
#
# \begin{equation*}
# \mathbb{C}(A^T)=\begin{bmatrix}
# 1   \\\
# 0 \\\
# 0
# \end{bmatrix} \subset \mathbb{R}^3
# \end{equation*}
#
#
# \begin{equation*}
# \mathbb{N}(A)=\begin{bmatrix}
# 0   \\\
# 1 \\\
# 0
# \end{bmatrix}+
# \begin{bmatrix}
# 0   \\\
# 0 \\\
# 1
# \end{bmatrix}
# \subset \mathbb{R}^3
# \end{equation*}
#
# Free variable 위치는 -를 붙여주고 자시자신은 1
#
# \begin{equation*}
# \mathbb{N}(A^T)=\begin{bmatrix}
# 0   \\\
# 1
# \end{bmatrix}
# \subset \mathbb{R}^2
# \end{equation*}
#
#
# Independent vector의 개수로 column space diemension을 알 수 있다.
#
# * Subspace의 특징
#
# 차원 같은 것 끼리는 수직이다.
#
# * $N(A)$ 와 $\mathbb{C}(A^T)$   는 수직관계
#
# * $N(A^T)$ 와 $\mathbb{C}(A)$ 는 수직 관계
#
#
#
# \begin{equation*}
# \mathbf{A}=\begin{bmatrix}
# 1 & 3 & 3 & 2 \\\
# 2 & 6 & 9 & 7 \\\
# -1 & -3 & 3 & 4
# \end{bmatrix}->
# \mathbf{U}=\begin{bmatrix}
# 1 & 3 & 3 & 2 \\\
# 0 & 0 & 3& 3 \\\
# 0 & 0 & 0 & 0
# \end{bmatrix}
# \end{equation*}
#
#
# * Row space of A
#
# -> non zero rows of $U$ are a basis, and the of pivots( or non-zero rows) is the dimension of row space of $A$ or $U$
#
# dim(A) = dim(U)   -> No change of dimension by $G.E$
#
# * Null space of A
#
# -> by elimination $ Ax=0$ -> $Ux=0$
#
# nullspaces of $A$ and $U$ are the same. its dimension is n-r. the special solution are a basis
#
# * Column space of A
#
# -> The pivot columns of A(or U) are a basis
#
# Dim(A) and Dim($\mathbb{C}(A)$ equals the rank r -> row space dim
#
# number of independent columns equals number of independent rows
#
# * Left nullspace of A ( $A^T$ nullspace )
#
#
# Dim($\mathbb{C}(A)$) + Dim(N($A^T$)) = m
#
# ( rank(r)      + (m-r))
#
#
# Dim($\mathbb{C}(A^T)$) + Dim(N(A)) = n
#
# ( rank (r)     + (n-r) )
#
#
#
# ex)
# \begin{equation*}
# \mathbf{A}=\begin{bmatrix}
# 1 & 2 \\
# 3 & 6
# \end{bmatrix}-> G.E ->
# \begin{bmatrix}
# 1 & 2 \\
# 0 & 0
# \end{bmatrix}
# \end{equation*}
#
# \begin{equation*}
# \mathbf{A^T}=\begin{bmatrix}
# 1 & 3 \\
# 2 & 6
# \end{bmatrix}
# \end{equation*}
#
#
# \begin{equation*}
# \mathbb{C}(A)=\begin{bmatrix}
# 1   \\\
# 3
# \end{bmatrix}
# \end{equation*}
#
#
# \begin{equation*}
# \mathbb{C}(A^T)=\begin{bmatrix}
# 1   \\\
# 2
# \end{bmatrix}
# \end{equation*}
#
#
# \begin{equation*}
# \mathbb{N}(A)=\begin{bmatrix}
# -2   \\\
# 1
# \end{bmatrix}
# \end{equation*}
#
# Free variable 위치는 -를 붙여주고 자시자신은 1
#
# \begin{equation*}
# \mathbb{N}(A^T)=\begin{bmatrix}
# -3   \\\
# 1
# \end{bmatrix}
# \subset \mathbb{R}^2
# \end{equation*}
#
#
# ## Existence of Inverses ( $A_{m\times n}$)
#
# (1) square case
#
# $ AA^{-1} = A^{-1}A = I $
#
# (2) $A_{m\times n}$ , $m<n$  ( 열의 개수 더 많음 )
#
# 오른쪽에 Inverse가 존재해서 -> Right inverse 라고 함
#
# 직사각형(가로가 긴 $A$) X 직사각형 ( 세로가 긴 $A^{-1}$) = mxm형태의 $I$
#
# 오른쪽에 붙지 않으면, 역행력이 존재하지 않음
#
# (3) $A_{m \times n}$ , $m>n$  ( 행의 개수 더 많음 )
#
# 직사각형(가로가 긴 $A^{-1}$) X 직사각형 ( 세로가 긴 $A$) = mxm형태의 $I$
#
# 역행렬이 왼쪽에 와야한다. -> Left inverse
#
# * $Ax=b$일 때
#
# 만약에 left-inverser가 존재한다면
#
# $$A^{-1}Ax = A^{-1}b$$
# $$x=A^{-1}b$$
#
# Unique한 X를 구할 수 있음
